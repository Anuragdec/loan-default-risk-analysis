# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cfd6876d-b5ea-4496-8135-898c35f654df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfd6876d-b5ea-4496-8135-898c35f654df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Loan_default_prediction.csv')
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
df.shape
# Out:
# (2999, 18)

# %%
df['Default'].mean()
# Out:
# np.float64(0.1237079026342114)

# %%
df.groupby('LoanPurpose')['Default'].mean()
# Out:
# LoanPurpose
# Auto         0.121464
# Business     0.130053
# Education    0.124585
# Home         0.103503
# Other        0.140234
# Name: Default, dtype: float64

# %% [markdown]
# pandas groupby = SQL GROUP BY

# %%
df[df['Income']>50000]
# Out:
#           LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0     I38PQUQS96   56   85994       50587          520              80
# 1     HPSK72WA7R   69   50432      124440          458              15
# 2     C1OZ6DPJ8Y   46   84208      129188          451              26
# 5     A9S62RQ7US   25   90298       90448          720              18
# 6     H8GXPAOS71   38  111188      177025          429              80
# ...          ...  ...     ...         ...          ...             ...
# 2994  BRYJU6JNNM   66  126094      177099          554              11
# 2995  25SWN6MN82   38   84120      132382          548              96
# 2996  T1OLOPDQDX   52   99629       86409          575             110
# 2997  AFO6U7AK8Z   49  118365      107915          438              37
# 2998  WRBUH95HNY   47   91796       43994          304              96
#
#       NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# 1.Task one ->show only rows where CreditScore < 600

# %%
df[df['CreditScore']<600]
# Out:
#           LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0     I38PQUQS96   56   85994       50587          520              80
# 1     HPSK72WA7R   69   50432      124440          458              15
# 2     C1OZ6DPJ8Y   46   84208      129188          451              26
# 6     H8GXPAOS71   38  111188      177025          429              80
# 7     0HGZQKJ36W   56  126802      155511          531              67
# ...          ...  ...     ...         ...          ...             ...
# 2994  BRYJU6JNNM   66  126094      177099          554              11
# 2995  25SWN6MN82   38   84120      132382          548              96
# 2996  T1OLOPDQDX   52   99629       86409          575             110
# 2997  AFO6U7AK8Z   49  118365      107915          438              37
# 2998  WRBUH95HNY   47   91796       43994          304              96
#
#       NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# 2.Groupby: recreate your (average default rate by income bracket)

# %%
df['IncomeBracket'] = df['Income'].apply(lambda x: 'Low' if x < 70000 else ('Medium' if x < 100000 else 'High'))
df.groupby(['IncomeBracket'])['Default'].mean()*100
# Out:
# IncomeBracket
# High      10.582960
# Low       14.435484
# Medium    11.490683
# Name: Default, dtype: float64

# %% [markdown]
# 3. Combine filter + groupby: average default rate by LoanPurpose, but only for loans where LoanAmount > 100000

# %%
df[df['LoanAmount']> 100000].groupby(['LoanPurpose'])['Default'].mean()*100
# Out:
# LoanPurpose
# Auto         14.247312
# Business     12.500000
# Education    15.926893
# Home         12.010444
# Other        15.656566
# Name: Default, dtype: float64

# %% [markdown]
# 4.Recreate your Q1 (overall default rate) using .mean() directly on the Default column

# %%
df['Default'].mean()*100
# Out:
# np.float64(12.37079026342114)
